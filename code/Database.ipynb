# %%
#import required packages
import wrds
import pandas as pd
import datetime
import pymysql

# %%
#establish WRDS connection
db = wrds.Connection(wrds_username='pankick')
#password: Pat940716
#db.raw_sql('SELECT date,dji FROM djones.djdaily LIMIT 5')
# Out:
# Loading library list...
# Done

# %%
now = datetime.datetime.now()
today = now.strftime("%Y-%m-%d")
today

# %%
datetime.datetime.now().strftime("%Y-%m-%d")

# %%
#db.create_pgpass_file()

# %%
#help(db.get_table)
#help(db.raw_sql)

# %%
#df = db.raw_sql('SELECT date,dji FROM djones.djdaily LIMIT 10;', date_cols = ['date'])

# %%
#db.list_libraries()

# %%
#db.list_tables(library="compd")

# %%
#db.describe_table(library="compd", table="secd")

# %%
data = db.raw_sql("SELECT * FROM compd.names WHERE conm LIKE '%%BOX%%';")
data

# %%
sample_sql = "SELECT * FROM compd.secd WHERE tic = 'NVET' AND datadate >= '2015-01-01' LIMIT 5;"
data1 = db.raw_sql(sample_sql)
list(data1)
# Out:
# ['gvkey',
#  'iid',
#  'datadate',
#  'tic',
#  'cusip',
#  'conm',
#  'curcddv',
#  'capgn',
#  'cheqv',
#  'div',
#  'divd',
#  'divdpaydateind',
#  'divsp',
#  'dvrated',
#  'paydateind',
#  'anncdate',
#  'capgnpaydate',
#  'cheqvpaydate',
#  'divdpaydate',
#  'divsppaydate',
#  'paydate',
#  'recorddate',
#  'curcdd',
#  'adrrc',
#  'ajexdi',
#  'cshoc',
#  'cshtrd',
#  'dvi',
#  'eps',
#  'epsmo',
#  'prccd',
#  'prchd',
#  'prcld',
#  'prcod',
#  'prcstd',
#  'trfd',
#  'exchg',
#  'secstat',
#  'tpci',
#  'cik',
#  'fic']

# %%
#Create tables for company performance data 
sql =
# Out:
# '7'

# %%
def searchtic():
    name = input("Enter company name:").upper()
    sql = "SELECT tic, conm FROM compd.names WHERE conm LIKE '%%{}%%';".format(name)
    data = db.raw_sql(sql)
    return data

# %%
#Search conmay tic by its partial name
def searchtic(*n):
    if len(n) == 0:
        name = input("Enter company name:").upper()
        sql = "SELECT tic, conm FROM compd.names WHERE conm LIKE '%%{}%%';".format(name)
    elif len(n) == 1:
        name = n[0].upper()
        sql = "SELECT tic, conm FROM compd.names WHERE conm LIKE '%%{}%%';".format(name)
    else:
        sql = "SELECT tic, conm FROM compd.names WHERE conm LIKE '%%{}%%';".format(n[0].upper())
        for name in n[1:]:
            add = " AND conm LIKE '%%{}%%'".format(name.upper())
            sql = sql[:-1] + add + ";"
    
    data = db.raw_sql(sql)
    return data

# %%
searchtic()
# Out:
# Enter company name:micro
#         tic                          conm
# 0       AMD        ADVANCED MICRO DEVICES
# 1     AMMS.         AMERICAN MICROSYSTEMS
# 2     3AUMI    AUTOMATED MICROSYSTEMS INC
# 3     3MFLU       MICROFLUIDICS INTL CORP
# 4      CRMK  CERMETEK MICROELECTRNICS INC
# 5      CNMW      CINCINNATI MICROWAVE INC
# 6      COMI    COMPUTER MICROFILM CORP-GA
# 7      CMCR    COMPUTER MICROGRAPHICS INC
# 8    3EIPME             EIP MICROWAVE INC
# 9     2375B        EXTEK MICROSYSTEMS INC
# 10    GMW.1        GENERAL MICROWAVE CORP
# 11    3HTEK        HYTEK MICROSYSTEMS INC
# 12    IMCIC  INTEGRATED MICROCIRCUITS INC
# 13     MCRD                   MICRO D INC
# 14   MGEN.1            MICRO GENERAL CORP
# 15   MCRO.1                MICRO MASK INC
# 16     MCRS            MICROS SYSTEMS INC
# 17    MBMI.          MICRO BIO MEDICS INC
# 18    4425B       MICROFAST SOFTWARE CORP
# 19     MISY    MICRO SECURITY SYSTEMS INC
# 20    MBLSE      MICROBIOLOGICAL SCIENCES
# 21     MMEM    MICROCOMPUTER MEMORIES INC
# 22     MICD                MICRODATA CORP
# 23    MIC.2                  MICRODOT INC
# 24     MCDY                MICRODYNE CORP
# 25    3MICC                MICRON CORP/TX
# 26       MU         MICRON TECHNOLOGY INC
# 27     MPAD       MICROPAC INDUSTRIES INC
# 28     MSCC                MICROSEMI CORP
# 29    MSON.              MICROSONICS CORP
# ..      ...                           ...
# 111   MBST.                 MICROBEST INC
# 112    EMCC      EUROPEAN MICRO HLDGS INC
# 113    MSTR             MICROSTRATEGY INC
# 114     MFI            MICROFINANCIAL INC
# 115   MBXBF       MICROBIX BIOSYSTEMS INC
# 116   JMICE  JEREMYS MICROBATCH ICE CREAM
# 117    CCMP   CABOT MICROELECTRONICS CORP
# 118    TUNE                 MICROTUNE INC
# 119   SMDI.      SIRENZA MICRODEVICES INC
# 120    OIIM     O2MICRO INTERNATIONAL LTD
# 121    MIIS                MICROISLET INC
# 122  MCHP.P     MICROCHIP TECH- PRO FORMA
# 123    CSCD         CASCADE MICROTECH INC
# 124   0106B    MILLIPORE MICROELECTRONICS
# 125    MCHU          MICROHOLDINGS US INC
# 126  NETL.1     NETLOGIC MICROSYSTEMS INC
# 127   MCTYF   MICROPLANET TECHNOLOGY CORP
# 128    HITT        HITTITE MICROWAVE CORP
# 129     PZI   INVESCO ZACKS MICRO CAP ETF
# 130     FDM   FIRST TR DJS MICROCAP INDEX
# 131    VIMC        VIMICRO INTL CORP -ADR
# 132    MITI                  MICROMET INC
# 133     IWC         ISHARES MICRO-CAP ETF
# 134   AMD.P  ADVANCED MICRO DV -PRO FORMA
# 135    SMCI      SUPER MICRO COMPUTER INC
# 136    ALGM     ALLEGRO MICROSYSTEMS-REDH
# 137     RDA  RDA MICROELECTRONCS INC -ADR
# 138     UMC  UNITED MICROELECTRONICS CORP
# 139   TMICY               TREND MICRO INC
# 140    MFGP          MICRO FOCUS INTL PLC
#
# [141 rows x 2 columns]

# %%
#test query here
sql = "SELECT tic, conm FROM compd.names WHERE conm LIKE '%%{}%%';"
db.raw_sql(sql)

# %%
#create functions for data access
def getdailystock(tic, start, end, count):
    tic = input('Enter company tic:')
    start = input('Enter start date as yyyy-mm-dd:')
    end = input('Enter end date as yyyy-mm-dd:')
    count = int(input('Enter number of rows to display:'))
    sql = """SELECT * FROM compd.secd WHERE tic = '%s' AND datadate >= '%s' AND datadate <= '%s' LIMIT %d ;""" % (tic, start, end, count)
    data = db.raw_sql(sql)
    return data

# %%
def getdailystock():
    select = input('Enter the information you want to retrieve (separate by comma, leaving it blank will display all):')
    tic = input('Enter company tic:')
    start = input('Enter start date as yyyy-mm-dd:')
    end = input('Enter end date as yyyy-mm-dd:')
    count = int(input('Enter number of rows to display:'))
    if select == '':
        select = '*'
    sql = """SELECT %s FROM compd.secd WHERE tic = '%s' AND datadate >= '%s' AND datadate <= '%s' LIMIT %d ;""" % (select, tic, start, end, count)
    data = db.raw_sql(sql)
    return data

# %%
getdailystock()

# %%
def gettoday():
    date = datetime.datetime.now().strftime("%Y-%m-%d")
    count = input('Enter number of rows to display:')
    if count == '':
        sql = """SELECT * FROM compd.secd WHERE datadate = '%s' ;""" % (date)
    else: 
        count = int(count)
        sql = """SELECT * FROM compd.secd WHERE datadate = '%s' LIMIT %d ;""" % (date, count)
    data = db.raw_sql(sql)
    return data

# %%
def getyesterday():
    date = (datetime.datetime.now() - datetime.timedelta(1)).strftime("%Y-%m-%d")
    count = input('Enter number of rows to display:')
    if count == '':
        sql = """SELECT * FROM compd.secd WHERE datadate = '%s' ;""" % (date)
    else: 
        count = int(count)
        sql = """SELECT * FROM compd.secd WHERE datadate = '%s' LIMIT %d ;""" % (date, count)
    data = db.raw_sql(sql)
    return data

# %%
#Get yesterday's company data
def getyesterday():
    date = (datetime.datetime.now() - datetime.timedelta(1)).strftime("%Y-%m-%d")
    count = input('Enter number of rows to display:')
    if count == '':
        sql = "SELECT * FROM compd.secd WHERE datadate = '{}' ;".format(date)
    else: 
        count = int(count)
        sql = "SELECT * FROM compd.secd WHERE datadate = '{}' LIMIT {} ;" .format(date, count)
    data = db.raw_sql(sql)
    return data

# %%
getyesterday()

# %%
ipo = pd.read_csv("ipo.csv")
names = ipo.iloc[:,1]

# %%
str(list(names))[1:-1]

# %%
#Get all company data for companies listed in the csv file(column name is Symbol for tic)
def getfromlist():
    url = input("Please type in your file url:")
    names = list(pd.read_csv(url).loc[:,'Symbol'])
    sql = "SELECT * FROM compd.secd WHERE tic IN ({}) AND datadate >= '2016-01-01' ORDER BY tic;".format(str(names)[1:-1])
    data = db.raw_sql(sql)
    return data

# %%
#Get company tic list from csv (column name is Symbol for tic)
def ticfromfile(*u):
    if len(u) == 0:
        url = input("Please type in your file url:")
    else:
        url = u[0]
    names = pd.read_csv(url).loc[:,'Symbol']
    return list(names)

# %%
def get_daily_update():
    url = "ipo.csv"
    names = pd.read_csv(url).loc[:,'Symbol']
    date1 = (datetime.datetime.now() - datetime.timedelta(5)).strftime("%Y-%m-%d")
    date2 = (datetime.datetime.now() - datetime.timedelta(1)).strftime("%Y-%m-%d")
    #modify date input later
    sql = "SELECT * FROM compd.secd WHERE tic IN ({}) AND datadate >= '{}' AND datadate <= '{}' ORDER BY tic;".format(str(list(names))[1:-1], date1, date2)
    data = db.raw_sql(sql)
    return data

# %%
(datetime.datetime.now() - datetime.timedelta(6)).strftime("%Y-%m-%d")
# Out:
# '2019-05-02'

# %%
get_daily_update()
# Out:
#       gvkey iid    datadate    tic      cusip                          conm  \
# 0    026270  01  2019-05-03   ABTX  01748H107     ALLEGIANCE BANCSHARES INC
# 1    025904  01  2019-05-03   ACRS  00461U105      ACLARIS THERAPEUTICS INC
# 2    023574  90  2019-05-03   ADAP  00653A107      ADAPTIMMUNE THERAPEUTICS
# 3    023335  01  2019-05-03   ADRO  00739L101             ADURO BIOTECH INC
# 4    025077  01  2019-05-03   AIMT  00900T107      AIMMUNE THERAPEUTICS INC
# 5    022853  01  2019-05-03    AJX  38983D300               GREAT AJAX CORP
# 6    024135  01  2019-05-03   ALRM  011642105        ALARM.COM HOLDINGS INC
# 7    034466  01  2019-05-03  ANDAU  G04415116           ANDINA ACQ CORP III
# 8    024071  01  2019-05-03   APPF  03783C100                  APPFOLIO INC
# 9    024422  01  2019-05-03   AQMS  03837J101               AQUA METALS INC
# 10   022604  90  2019-05-03   ASND  04351P101       ASCENDIS PHARMA AS -ADR
# 11   022704  01  2019-05-03   AVGR  053734208                   AVINGER INC
# 12   026349  01  2019-05-03   AXSM  05464T104       AXSOME THERAPEUTICS INC
# 13   022927  01  2019-05-03   BLPH  078771102  BELLEROPHON THERAPEUTICS INC
# 14   254381  90  2019-05-03   BNTC  082053307         BENITEC BIOPHARMA LTD
# 15   020088  01  2019-05-03    BOX  10316T104                       BOX INC
# 16   023407  01  2019-05-03   BPMC  09627Y109      BLUEPRINT MEDICINES CORP
# 17   023433  01  2019-05-03    BSM  09225M101       BLACK STONE MINERALS LP
# 18   297094  90  2019-05-03   BVXV  09073Q105      BIONDVAX PHARMACEUTICALS
# 19   023703  90  2019-05-03   BZUN  06684L103               BAOZUN INC -ADR
# 20   023980  01  2019-05-03   CATB  14875P206     CATABASIS PHARMACEUTICALS
# 21   021965  01  2019-05-03   CCRC  G2118P102  CHINA CUSTOMER RELATNS  CTRS
# 22   023358  01  2019-05-03   CDTX  171757107       CIDARA THERAPEUTICS INC
# 23   024084  01  2019-05-03   CFMS  20717E101                 CONFORMIS INC
# 24   023556  01  2019-05-03   CHCT  20369C106    COMMUNITY HEALTHCARE TRUST
# 25   024523  01  2019-05-03   CHMA  16706W102                   CHIASMA INC
# 26   282608  90  2019-05-03   CLLS  15117K103                  CELLECTIS SA
# 27   025105  01  2019-05-03   CNFR  20731J102          CONIFER HOLDINGS INC
# 28   023555  01  2019-05-03   COLL  19459J104  COLLEGIUM PHARMACEUTICAL INC
# 29   026112  01  2019-05-03   CTMX  23284F105       CYTOMX THERAPEUTICS INC
# ..      ...  ..         ...    ...        ...                           ...
# 102  024501  01  2019-05-03    RPD  753422104                    RAPID7 INC
# 103  023422  01  2019-05-03   RTTR  767836307    RITTER PHARMACEUTICALS INC
# 104  024905  01  2019-05-03    RUN  86771W105                    SUNRUN INC
# 105  293919  01  2019-05-03   SBBP  G85347105    STRONGBRIDGE BIOPHARMA PLC
# 106  023119  01  2019-05-03   SEDG  83417M104    SOLAREDGE TECHNOLOGIES INC
# 107  025898  01  2019-05-03   SGRY  86881A100          SURGERY PARTNERS INC
# 108  022672  01  2019-05-03   SHAK  819047101               SHAKE SHACK INC
# 109  023650  01  2019-05-03   SHOP  82509L107                   SHOPIFY INC
# 110  271357  90  2019-05-03   SMMT  86627R102       SUMMIT THERAPEUTICS PLC
# 111  026367  01  2019-05-03     SQ  852234103                    SQUARE INC
# 112  022603  01  2019-05-03    SUM  86614U100          SUMMIT MATERIALS INC
# 113  022138  01  2019-05-03   TANH  G8675X107          TANTECH HOLDINGS LTD
# 114  022697  01  2019-05-03   TCON  89237H100    TRACON PHARMACEUTICALS INC
# 115  024249  01  2019-05-03   TDOC  87918A105            TELADOC HEALTH INC
# 116  026494  01  2019-05-03   TEAM  G06242104            ATLASSIAN CORP PLC
# 117  024638  01  2019-05-03    TRU  89400J107                    TRANSUNION
# 118  022180  01  2019-05-03   UFAB  90915J103        UNIQUE FABRICATING INC
# 119  021515  01  2019-05-03   UNVR  91336L107                    UNIVAR INC
# 120  023432  01  2019-05-03   VIRT  928254101           VIRTU FINANCIAL INC
# 121  021032  01  2019-05-03   VKTX  92686J106       VIKING THERAPEUTICS INC
# 122  024515  01  2019-05-03   VTVT  918385105          VTV THERAPEUTICS INC
# 123  026341  01  2019-05-03   VYGR  92915B106      VOYAGER THERAPEUTICS INC
# 124  023843  01  2019-05-03   WING  974155103                  WINGSTOP INC
# 125  026340  01  2019-05-03    WVE  Y95308105        WAVE LIFE SCIENCES LTD
# 126  023297  01  2019-05-03   XBIT  98400H102                  XBIOTECH INC
# 127  034671  01  2019-05-03   XCOM  74347B136  ULTRA COM SVC SELECT SEC ETF
# 128  189757  01  2019-05-03   XELB  98400M101               XCEL BRANDS INC
# 129  026537  90  2019-05-03    YRD  98585L100             YIRENDAI LTD -ADR
# 130  021003  01  2019-05-03   ZSAN  98979H202            ZOSANO PHARMA CORP
# 131  025128  01  2019-05-03   ZYNE  98986X109   ZYNERBA PHARMACEUTICALS INC
#
#     curcddv capgn cheqv  div  ...     prchd     prcld     prcod  prcstd  \
# 0      None  None  None  NaN  ...   35.9700   34.9500   34.9500     3.0
# 1      None  None  None  NaN  ...    6.3750    6.0100    6.0600     3.0
# 2      None  None  None  NaN  ...    4.8900    4.5700    4.6500     3.0
# 3      None  None  None  NaN  ...    4.3300    4.0800    4.2000     3.0
# 4      None  None  None  NaN  ...   20.0770   19.5562   19.7900     3.0
# 5      None  None  None  NaN  ...   14.2300   14.1150   14.1300     3.0
# 6      None  None  None  NaN  ...   71.4000   70.1800   70.6700     3.0
# 7      None  None  None  NaN  ...   10.2800   10.2600       NaN     4.0
# 8      None  None  None  NaN  ...   94.5900   84.2800   88.0000     3.0
# 9      None  None  None  NaN  ...    2.5550    2.3700    2.3700     3.0
# 10     None  None  None  NaN  ...  121.5600  118.5700  119.3900     3.0
# 11     None  None  None  NaN  ...    0.6430    0.5703    0.5800     3.0
# 12     None  None  None  NaN  ...   18.0200   17.2800   17.4800     3.0
# 13     None  None  None  NaN  ...    0.6400    0.6215    0.6338     3.0
# 14     None  None  None  NaN  ...    2.0000    1.9095    1.9963     3.0
# 15     None  None  None  NaN  ...   20.8400   20.3980   20.4000     3.0
# 16     None  None  None  NaN  ...   79.5100   76.2400   76.7900     3.0
# 17     None  None  None  NaN  ...   18.4400   18.0000   18.0300     3.0
# 18     None  None  None  NaN  ...    7.0500    6.7800    6.7800     3.0
# 19     None  None  None  NaN  ...   49.1000   47.8200   48.1000     3.0
# 20     None  None  None  NaN  ...    7.8200    7.4700    7.5400     3.0
# 21     None  None  None  NaN  ...   12.0300   11.2600   12.0300     3.0
# 22     None  None  None  NaN  ...    2.4800    2.2540    2.2800     3.0
# 23     None  None  None  NaN  ...    2.6600    2.4000    2.4200     3.0
# 24     None  None  None  NaN  ...   37.4450   36.6700   36.7100     3.0
# 25     None  None  None  NaN  ...    6.1300    5.8700    5.8900     3.0
# 26     None  None  None  NaN  ...   20.1700   19.6600   19.8400     3.0
# 27     None  None  None  NaN  ...    4.7000    4.4900       NaN     4.0
# 28     None  None  None  NaN  ...   14.2300   13.4000   14.1600     3.0
# 29     None  None  None  NaN  ...   10.0600    9.8500    9.9000     3.0
# ..      ...   ...   ...  ...  ...       ...       ...       ...     ...
# 102    None  None  None  NaN  ...   57.0000   52.3100   54.2800     3.0
# 103    None  None  None  NaN  ...    0.8000    0.7500    0.7800     3.0
# 104    None  None  None  NaN  ...   16.0850   15.5000   15.5000     3.0
# 105    None  None  None  NaN  ...    3.6700    3.4100    3.6700     3.0
# 106    None  None  None  NaN  ...   44.9700   44.1500   44.2700     3.0
# 107    None  None  None  NaN  ...   11.1800   10.8900   10.9200     3.0
# 108    None  None  None  NaN  ...   67.0200   59.1500   66.9500     3.0
# 109    None  None  None  NaN  ...  266.4000  254.7900  259.0000     3.0
# 110    None  None  None  NaN  ...    1.8200    1.6300    1.7000     3.0
# 111    None  None  None  NaN  ...   68.6700   66.6000   67.9100     3.0
# 112    None  None  None  NaN  ...   17.7700   17.2000   17.6400     3.0
# 113    None  None  None  NaN  ...    1.5700    1.5400    1.5500     3.0
# 114    None  None  None  NaN  ...    0.6800    0.6300    0.6314     3.0
# 115    None  None  None  NaN  ...   60.9900   57.5350   57.7500     3.0
# 116    None  None  None  NaN  ...  111.7000  109.4577  110.3300     3.0
# 117    None  None  None  NaN  ...   68.6300   67.7750   68.4400     3.0
# 118    None  None  None  NaN  ...    3.8411    3.7064    3.8000     3.0
# 119    None  None  None  NaN  ...   22.3400   21.8000   21.9200     3.0
# 120    None  None  None  NaN  ...   23.7800   22.6500   23.6900     3.0
# 121    None  None  None  NaN  ...    8.4700    8.0000    8.0500     3.0
# 122    None  None  None  NaN  ...    1.6717    1.5000    1.5700     3.0
# 123    None  None  None  NaN  ...   22.7900   21.7000   21.7800     3.0
# 124    None  None  None  NaN  ...   76.0900   74.9600   75.3300     3.0
# 125    None  None  None  NaN  ...   28.0400   26.7725   27.8000     3.0
# 126    None  None  None  NaN  ...    9.4050    8.9900    9.2700     3.0
# 127    None  None  None  NaN  ...   49.5656   49.5656   49.5656     3.0
# 128    None  None  None  NaN  ...    1.3800    1.2800    1.2800     3.0
# 129    None  None  None  NaN  ...   16.9600   16.0000   16.0900     3.0
# 130    None  None  None  NaN  ...    3.8180    3.6400    3.6900     3.0
# 131    None  None  None  NaN  ...   11.8300    9.9500   10.6700     3.0
#
#          trfd exchg secstat tpci         cik  fic
# 0         NaN  14.0       A    0  0001642081  USA
# 1         NaN  14.0       A    0  0001557746  USA
# 2         NaN  14.0       A    F  0001621227  GBR
# 3         NaN  14.0       A    0  0001435049  USA
# 4         NaN  14.0       A    0  0001631650  USA
# 5    1.384030  11.0       A    0  0001614806  USA
# 6         NaN  14.0       A    0  0001459200  USA
# 7         NaN  14.0       A    0  0001691936  CYM
# 8         NaN  14.0       A    0  0001433195  USA
# 9         NaN  14.0       A    0  0001621832  USA
# 10        NaN  14.0       A    F  0001612042  DNK
# 11        NaN  14.0       A    0  0001506928  USA
# 12        NaN  14.0       A    0  0001579428  USA
# 13        NaN  14.0       A    0  0001600132  USA
# 14   1.001143  14.0       A    F  0001552795  AUS
# 15        NaN  11.0       A    0  0001372612  USA
# 16        NaN  14.0       A    0  0001597264  USA
# 17   1.306687  11.0       A    0  0001621434  USA
# 18        NaN  14.0       A    F  0001611747  ISR
# 19        NaN  14.0       A    F  0001625414  CYM
# 20        NaN  14.0       A    0  0001454789  USA
# 21        NaN  14.0       A    0  0001620664  VGB
# 22        NaN  14.0       A    0  0001610618  USA
# 23        NaN  14.0       A    0  0001305773  USA
# 24   1.266214  11.0       A    0  0001631569  USA
# 25        NaN  14.0       A    0  0001339469  USA
# 26        NaN  14.0       A    F  0001627281  FRA
# 27        NaN  14.0       A    0  0001502292  USA
# 28        NaN  14.0       A    0  0001267565  USA
# 29        NaN  14.0       A    0  0001501989  USA
# ..        ...   ...     ...  ...         ...  ...
# 102       NaN  14.0       A    0  0001560327  USA
# 103       NaN  14.0       A    0  0001460702  USA
# 104       NaN  14.0       A    0  0001469367  USA
# 105       NaN  14.0       A    0  0001634432  IRL
# 106       NaN  14.0       A    0  0001419612  USA
# 107       NaN  14.0       A    0  0001638833  USA
# 108       NaN  11.0       A    0  0001620533  USA
# 109       NaN  11.0       A    0  0001594805  CAN
# 110       NaN  14.0       A    F  0001599298  GBR
# 111       NaN  11.0       A    0  0001512673  USA
# 112       NaN  11.0       A    0  0001621563  USA
# 113       NaN  14.0       A    0  0001588084  VGB
# 114       NaN  14.0       A    0  0001394319  USA
# 115       NaN  11.0       A    0  0001477449  USA
# 116       NaN  14.0       A    0  0001650372  GBR
# 117  1.004554  11.0       A    0  0001552033  USA
# 118  1.256795  12.0       A    0  0001617669  USA
# 119       NaN  11.0       A    0  0001494319  USA
# 120  1.196411  14.0       A    0  0001592386  USA
# 121       NaN  14.0       A    0  0001607678  USA
# 122       NaN  14.0       A    0  0001641489  USA
# 123       NaN  14.0       A    0  0001640266  USA
# 124  1.264951  14.0       A    0  0001636222  USA
# 125       NaN  14.0       A    0  0001631574  SGP
# 126       NaN  14.0       A    0  0001626878  CAN
# 127  1.000682  17.0       A    %        None  USA
# 128       NaN  14.0       A    0  0001083220  USA
# 129  1.043011  11.0       A    F  0001631761  CYM
# 130       NaN  14.0       A    0  0001587221  USA
# 131       NaN  14.0       A    0  0001621443  USA
#
# [132 rows x 41 columns]

# %%
sql = 
cur.execute(sql)
conn.commit()

# %%
perform.head()
# Out:
#     gvkey iid    datadate   tic      cusip                          conm  \
# 0  022266  90  2016-01-04  AAAP  00790T100  ADVANCED ACCELERATR APP -ADR
# 1  022266  90  2018-01-12  AAAP  00790T100  ADVANCED ACCELERATR APP -ADR
# 2  022266  90  2018-01-16  AAAP  00790T100  ADVANCED ACCELERATR APP -ADR
# 3  022266  90  2016-01-05  AAAP  00790T100  ADVANCED ACCELERATR APP -ADR
# 4  022266  90  2016-01-06  AAAP  00790T100  ADVANCED ACCELERATR APP -ADR
#
#   curcddv capgn  cheqv  div  ...  prchd   prcld  prcod  prcstd trfd exchg  \
# 0    None  None    NaN  NaN  ...  31.20  29.355  30.75     3.0  NaN  14.0
# 1    None  None    NaN  NaN  ...  81.89  81.810  81.85     3.0  NaN  14.0
# 2    None  None    NaN  NaN  ...  81.90  81.820  81.85     3.0  NaN  14.0
# 3    None  None    NaN  NaN  ...  31.00  29.600  31.00     3.0  NaN  14.0
# 4    None  None    NaN  NaN  ...  30.58  29.210  30.58     3.0  NaN  14.0
#
#   secstat tpci         cik  fic
# 0       I    F  0001611787  FRA
# 1       I    F  0001611787  FRA
# 2       I    F  0001611787  FRA
# 3       I    F  0001611787  FRA
# 4       I    F  0001611787  FRA
#
# [5 rows x 41 columns]

# %%
import MySQLdb

# %%
df = getfromlist().tail()
# Out:
# Please type in your file url:ipo.csv

# %%
#Connecting to Mysql
import pandas as pd
import MySQLdb
from sqlalchemy import create_engine
host="isproject.czwxn60qeghl.us-east-1.rds.amazonaws.com"
port=3306
schema="IPO"
user="admin1234"
password="admin1234"

#conn = pymysql.connect(host, user=user,port=port,passwd=password, db=dbname)
#engine = create_engine('mysql+mysqlconnector://os.environ['user']:os.environ['password']@os.environ['host']:os.environ['port']/sandbox', echo=False)
#engine = create_engine('mysql+mysqlconnector://[user]:[password]@[host]:[port]/[schema]', echo=False)
#engine = create_engine('mysql+mysqlconnector://[admin1234]:[admin1234]@[isproject.czwxn60qeghl.us-east-1.rds.amazonaws.com]:[3306]/[IPO]', echo=False)
engine = create_engine("mysql+mysqldb://{}:{}@{}:{}/{}".format(user, password, host, port, schema))

db_connection= MySQLdb.connect(host,user,password,schema)

# %%
cur =db_connection.cursor()
sql = "SELECT * FROM perform;"
cur.execute(sql)
#conn.commit()
# Out:
# 5

# %%
lowball = pd.read_csv('merge_data_lowball.csv')
lowball.to_sql(name='lowball', con=engine, if_exists = 'replace', index=False)

# %%
#Create new table in database
perform.to_sql(name='perform', con=engine, if_exists = 'replace', index=False)

# %%
pd.read_sql("SELECT table_name FROM information_schema.tables WHERE table_type = 'base table' AND table_schema='IPO';", con=engine)
# Out:
#   table_name
# 0   ipo_char
# 1   ipo_info
# 2    lowball
# 3    perform
# 4       test

# %%
pd.read_sql("SELECT conm from perform GROUP BY conm ORDER BY datadate;", con=engine)
# Out:
#                              conm
# 0    ADVANCED ACCELERATR APP -ADR
# 1              HOULIHAN LOKEY INC
# 2                    MIMECAST LTD
# 3        MAXPOINT INTERACTIVE INC
# 4              TELADOC HEALTH INC
# 5            JM GLOBAL HOLDING CO
# 6        PRESS GANEY HOLDINGS INC
# 7                FOGO DE CHAO INC
# 8       CARBYLAN THERAPEUTICS INC
# 9                    CELLECTIS SA
# 10           NEXVET BIOPHARMA PLC
# 11      EASTERLY ACQUISITION CORP
# 12             PACE HOLDINGS CORP
# 13                ATYR PHARMA INC
# 14        JUPAI HOLDINGS LTD -ADR
# 15               INTEC PHARMA LTD
# 16          BIOTIE THERAPIES CORP
# 17      ALLEGIANCE BANCSHARES INC
# 18   QUINPARIO ACQUISITION CORP 2
# 19           WISDOMTREE COAL FUND
# 20                    APIGEE CORP
# 21         MIRNA THERAPEUTICS INC
# 22       FINTECH ACQUISITION CORP
# 23                     SQUARE INC
# 24                  REGENXBIO INC
# 25   FORTRESS TRANS INFRASTR INVS
# 26                    GODADDY INC
# 27     GP INVESTMENTS ACQUISITION
# 28      AVENUE FINANCIAL HOLDINGS
# 29        VIKING THERAPEUTICS INC
# ..                            ...
# 152            ATLASSIAN CORP PLC
# 153                  KEMPHARM INC
# 154              KITOV PHARMA LTD
# 155                 MESOBLAST LTD
# 156                 DAVIDSTEA INC
# 157              PURE STORAGE INC
# 158        PLTNM EGLE ACQSTON CRP
# 159          VTV THERAPEUTICS INC
# 160                      ETSY INC
# 161     HTG MOLECULAR DIAGNOSTICS
# 162               AQUA METALS INC
# 163         EQUITY BANCSHARES INC
# 164                   SHOPIFY INC
# 165                       EURONAV
# 166                       BOX INC
# 167               FLEX PHARMA INC
# 168            CPI CARD GROUP INC
# 169           ANDINA ACQ CORP III
# 170         INOVALON HOLDINGS INC
# 171    RITTER PHARMACEUTICALS INC
# 172     FRANKLIN FINL NETWORK INC
# 173  HENNESSY CAPITAL ACQ CORP IV
# 174          TANTECH HOLDINGS LTD
# 175                    FERRARI NV
# 176      OASMIA PHARMACEUTICAL AB
# 177                    TRANSUNION
# 178    TRACON PHARMACEUTICALS INC
# 179  ULTRA COM SVC SELECT SEC ETF
# 180    COMMUNITY HEALTHCARE TRUST
# 181       SUMMIT THERAPEUTICS PLC
#
# [182 rows x 1 columns]

# %%
colname = str(list(data1))[1:-1]

# %%
#Update company data
tics = ticfromfile()
tic = tics[10]
sql = "INSERT INTO {}({}) VALUES (v11,v12,...), (v21,v22,...), (vnn,vn2,...);".format(tic,colname)
sql
# Out:
# Please type in your file url:ipo.csv
# "INSERT INTO EURN('gvkey', 'iid', 'datadate', 'tic', 'cusip', 'conm', 'curcddv', 'capgn', 'cheqv', 'div', 'divd', 'divdpaydateind', 'divsp', 'dvrated', 'paydateind', 'anncdate', 'capgnpaydate', 'cheqvpaydate', 'divdpaydate', 'divsppaydate', 'paydate', 'recorddate', 'curcdd', 'adrrc', 'ajexdi', 'cshoc', 'cshtrd', 'dvi', 'eps', 'epsmo', 'prccd', 'prchd', 'prcld', 'prcod', 'prcstd', 'trfd', 'exchg', 'secstat', 'tpci', 'cik', 'fic') VALUES (v11,v12,...), (v21,v22,...), (vnn,vn2,...);"

# %%
db.close()
